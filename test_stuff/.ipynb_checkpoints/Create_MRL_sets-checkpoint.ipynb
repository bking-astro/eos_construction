# %%
# this is the notebook where I make MRL curves from the 1k EOSs produced in 'Create_EOS_sets'
import matplotlib.pyplot as plt
import numpy as np
import warnings
import time
warnings.filterwarnings('ignore')

# %%
import TOVsolver
import test_TOVsolver
max_p = 1350 #MeV/fm^3

# %%
cs5_test = np.load('../data/cs5test.npy')
start=time.time()
MRL = TOVsolver.solve(cs5_test, max_p)
#MRL_test = test_TOVsolver.solve(cs5_test, max_p)
print(time.time()-start)
# Out:
# 25.938282012939453

# %%
fig, ax = plt.subplots(1,2, figsize=(16,8))

olddata = np.loadtxt('../data/test.dat')

ax[0].plot(cs5_test[:,0], cs5_test[:,2])
ax[0].set_xlabel('Density (MeV/fm^3)')
ax[0].set_ylabel('Pressure (MeV/fm^3)')

ax[1].plot(MRL[:,0], MRL[:,1], label='og sovler')
ax[1].plot(olddata[:,0], olddata[:,1], label='old', linestyle='--')
# ax[1].plot(MRL_test[:,0], MRL_test[:,1], label='test solver')
ax[1].set_xlabel('Mass (Mo)')
ax[1].set_ylabel('Radius (km)')
ax[1].legend()

# %%
cs5EOS = np.load('../data/cs5EOS.npy')
cs5MRL_5 = np.zeros((MRL.shape[0],MRL.shape[1],5))
cs5MRL_10 = np.zeros((MRL.shape[0],MRL.shape[1],10))
cs5MRL_20 = np.zeros((MRL.shape[0],MRL.shape[1],20))

# %%
#benchmarking
window = 5


for i in range(window):
    # %time cs5MRL_5[:,:,i] = TOVsolver.solve(cs5EOS[:,:,i], max_p)
# Out:
# CPU times: user 49.2 s, sys: 626 ms, total: 49.9 s
# Wall time: 50.8 s
# CPU times: user 26 s, sys: 442 ms, total: 26.4 s
# Wall time: 27.5 s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <timed exec> in <module>
#
# ~/Documents/LANL_project/test_stuff/TOVsolver.py in solve(EOS_table, max_pressure, size)
#     138         leng = int(1e3)
#     139
# --> 140         sol = scipy.integrate.solve_ivp(TOV, t_span, y0, method='RK23', vectorized=True, args=(EOS_e,),rtol=1e-2,atol=0.0)
#     141         y = sol['y']
#     142
#
# /opt/anaconda3/lib/python3.8/site-packages/scipy/integrate/_ivp/ivp.py in solve_ivp(fun, t_span, y0, method, t_eval, dense_output, events, vectorized, args, **options)
#     574     status = None
#     575     while status is None:
# --> 576         message = solver.step()
#     577
#     578         if solver.status == 'finished':
#
# /opt/anaconda3/lib/python3.8/site-packages/scipy/integrate/_ivp/base.py in step(self)
#     179         else:
#     180             t = self.t
# --> 181             success, message = self._step_impl()
#     182
#     183             if not success:
#
# /opt/anaconda3/lib/python3.8/site-packages/scipy/integrate/_ivp/rk.py in _step_impl(self)
#     142             h_abs = np.abs(h)
#     143
# --> 144             y_new, f_new = rk_step(self.fun, t, y, self.f, h, self.A,
#     145                                    self.B, self.C, self.K)
#     146             scale = atol + np.maximum(np.abs(y), np.abs(y_new)) * rtol
#
# /opt/anaconda3/lib/python3.8/site-packages/scipy/integrate/_ivp/rk.py in rk_step(fun, t, y, f, h, A, B, C, K)
#      62     for s, (a, c) in enumerate(zip(A[1:], C[1:]), start=1):
#      63         dy = np.dot(K[:s].T, a[:s]) * h
# ---> 64         K[s] = fun(t + c * h, y + dy)
#      65
#      66     y_new = y + h * np.dot(K[:-1].T, B)
#
# /opt/anaconda3/lib/python3.8/site-packages/scipy/integrate/_ivp/base.py in fun(t, y)
#     136         def fun(t, y):
#     137             self.nfev += 1
# --> 138             return self.fun_single(t, y)
#     139
#     140         self.fun = fun
#
# /opt/anaconda3/lib/python3.8/site-packages/scipy/integrate/_ivp/base.py in fun_single(t, y)
#     123         if vectorized:
#     124             def fun_single(t, y):
# --> 125                 return self._fun(t, y[:, None]).ravel()
#     126             fun_vectorized = self._fun
#     127         else:
#
# /opt/anaconda3/lib/python3.8/site-packages/scipy/integrate/_ivp/base.py in fun_wrapped(t, y)
#      18
#      19     def fun_wrapped(t, y):
# ---> 20         return np.asarray(fun(t, y), dtype=dtype)
#      21
#      22     return fun_wrapped, y0
#
# /opt/anaconda3/lib/python3.8/site-packages/scipy/integrate/_ivp/ivp.py in <lambda>(t, x, fun)
#     512         # additional parameters.  Pass in the original fun as a keyword
#     513         # argument to keep it in the scope of the lambda.
# --> 514         fun = lambda t, x, fun=fun: fun(t, x, *args)
#     515         jac = options.get('jac')
#     516         if callable(jac):
#
# ~/Documents/LANL_project/test_stuff/TOVsolver.py in TOV(p, y, EOS_e)
#      85
#      86     num2 = (y[2] ** 2 + y[2] * F_ode(p, y[0], y[1], EOS_e)
# ---> 87             + yQ_ode(p, y[0], y[1], EOS_e)) * (np.sqrt(y[0]) - 2 * y[1])
#      88     den2 = (EOS_e(p) + p) * (y[1] + 4 * pi * p * y[0] ** (3 / 2))
#      89
#
# ~/Documents/LANL_project/test_stuff/TOVsolver.py in yQ_ode(p, y, m, EOS_e)
#      33     b = np.sqrt(y) - 2 * m
#      34
# ---> 35     one = (a / b) * (5 * EOS_e(p) + 9 * p + EOS_e.derivative(nu=1)(p) * (EOS_e(p) + p))
#      36     two = -6 * np.sqrt(y) / b
#      37     three = -4 * (m / b + a * p / b) ** 2
#
# /opt/anaconda3/lib/python3.8/site-packages/scipy/interpolate/interpolate.py in derivative(self, nu)
#    1014             c2 = self.c.copy()
#    1015         else:
# -> 1016             c2 = self.c[:-nu, :].copy()
#    1017
#    1018         if c2.shape[0] == 0:
#
# KeyboardInterrupt:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <timed exec> in <module>
#
# ~/Documents/LANL_project/test_stuff/TOVsolver.py in solve(EOS_table, max_pressure, size)
#     138         leng = int(1e3)
#     139
# --> 140         sol = scipy.integrate.solve_ivp(TOV, t_span, y0, method='RK23', vectorized=True, args=(EOS_e,),rtol=1e-2,atol=0.0)
#     141         y = sol['y']
#     142
#
# /opt/anaconda3/lib/python3.8/site-packages/scipy/integrate/_ivp/ivp.py in solve_ivp(fun, t_span, y0, method, t_eval, dense_output, events, vectorized, args, **options)
#     574     status = None
#     575     while status is None:
# --> 576         message = solver.step()
#     577
#     578         if solver.status == 'finished':
#
# /opt/anaconda3/lib/python3.8/site-packages/scipy/integrate/_ivp/base.py in step(self)
#     179         else:
#     180             t = self.t
# --> 181             success, message = self._step_impl()
#     182
#     183             if not success:
#
# /opt/anaconda3/lib/python3.8/site-packages/scipy/integrate/_ivp/rk.py in _step_impl(self)
#     142             h_abs = np.abs(h)
#     143
# --> 144             y_new, f_new = rk_step(self.fun, t, y, self.f, h, self.A,
#     145                                    self.B, self.C, self.K)
#     146             scale = atol + np.maximum(np.abs(y), np.abs(y_new)) * rtol
#
# /opt/anaconda3/lib/python3.8/site-packages/scipy/integrate/_ivp/rk.py in rk_step(fun, t, y, f, h, A, B, C, K)
#      62     for s, (a, c) in enumerate(zip(A[1:], C[1:]), start=1):
#      63         dy = np.dot(K[:s].T, a[:s]) * h
# ---> 64         K[s] = fun(t + c * h, y + dy)
#      65
#      66     y_new = y + h * np.dot(K[:-1].T, B)
#
# /opt/anaconda3/lib/python3.8/site-packages/scipy/integrate/_ivp/base.py in fun(t, y)
#     136         def fun(t, y):
#     137             self.nfev += 1
# --> 138             return self.fun_single(t, y)
#     139
#     140         self.fun = fun
#
# /opt/anaconda3/lib/python3.8/site-packages/scipy/integrate/_ivp/base.py in fun_single(t, y)
#     123         if vectorized:
#     124             def fun_single(t, y):
# --> 125                 return self._fun(t, y[:, None]).ravel()
#     126             fun_vectorized = self._fun
#     127         else:
#
# /opt/anaconda3/lib/python3.8/site-packages/scipy/integrate/_ivp/base.py in fun_wrapped(t, y)
#      18
#      19     def fun_wrapped(t, y):
# ---> 20         return np.asarray(fun(t, y), dtype=dtype)
#      21
#      22     return fun_wrapped, y0
#
# /opt/anaconda3/lib/python3.8/site-packages/scipy/integrate/_ivp/ivp.py in <lambda>(t, x, fun)
#     512         # additional parameters.  Pass in the original fun as a keyword
#     513         # argument to keep it in the scope of the lambda.
# --> 514         fun = lambda t, x, fun=fun: fun(t, x, *args)
#     515         jac = options.get('jac')
#     516         if callable(jac):
#
# ~/Documents/LANL_project/test_stuff/TOVsolver.py in TOV(p, y, EOS_e)
#      80
#      81     num1 = -4 * np.pi * EOS_e(p) * (y[0] ** (3 / 2)) * (np.sqrt(y[0]) - 2 * y[1])
# ---> 82     den1 = (EOS_e(p) + p) * (y[1] + 4 * pi * p * y[0] ** (3 / 2))
#      83
#      84     dy[1] = num1 / den1
#
# /opt/anaconda3/lib/python3.8/site-packages/scipy/interpolate/interpolate.py in __call__(self, x, nu, extrapolate)
#     910         out = np.empty((len(x), prod(self.c.shape[2:])), dtype=self.c.dtype)
#     911         self._ensure_c_contiguous()
# --> 912         self._evaluate(x, nu, extrapolate, out)
#     913         out = out.reshape(x_shape + self.c.shape[2:])
#     914         if self.axis != 0:
#
# /opt/anaconda3/lib/python3.8/site-packages/scipy/interpolate/interpolate.py in _evaluate(self, x, nu, extrapolate, out)
#     980     """
#     981     def _evaluate(self, x, nu, extrapolate, out):
# --> 982         _ppoly.evaluate(self.c.reshape(self.c.shape[0], self.c.shape[1], -1),
#     983                         self.x, x, nu, bool(extrapolate), out)
#     984
#
# KeyboardInterrupt:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <timed exec> in <module>
#
# ~/Documents/LANL_project/test_stuff/TOVsolver.py in solve(EOS_table, max_pressure, size)
#     138         leng = int(1e3)
#     139
# --> 140         sol = scipy.integrate.solve_ivp(TOV, t_span, y0, method='RK23', vectorized=True, args=(EOS_e,),rtol=1e-2,atol=0.0)
#     141         y = sol['y']
#     142
#
# /opt/anaconda3/lib/python3.8/site-packages/scipy/integrate/_ivp/ivp.py in solve_ivp(fun, t_span, y0, method, t_eval, dense_output, events, vectorized, args, **options)
#     574     status = None
#     575     while status is None:
# --> 576         message = solver.step()
#     577
#     578         if solver.status == 'finished':
#
# /opt/anaconda3/lib/python3.8/site-packages/scipy/integrate/_ivp/base.py in step(self)
#     179         else:
#     180             t = self.t
# --> 181             success, message = self._step_impl()
#     182
#     183             if not success:
#
# /opt/anaconda3/lib/python3.8/site-packages/scipy/integrate/_ivp/rk.py in _step_impl(self)
#     142             h_abs = np.abs(h)
#     143
# --> 144             y_new, f_new = rk_step(self.fun, t, y, self.f, h, self.A,
#     145                                    self.B, self.C, self.K)
#     146             scale = atol + np.maximum(np.abs(y), np.abs(y_new)) * rtol
#
# /opt/anaconda3/lib/python3.8/site-packages/scipy/integrate/_ivp/rk.py in rk_step(fun, t, y, f, h, A, B, C, K)
#      62     for s, (a, c) in enumerate(zip(A[1:], C[1:]), start=1):
#      63         dy = np.dot(K[:s].T, a[:s]) * h
# ---> 64         K[s] = fun(t + c * h, y + dy)
#      65
#      66     y_new = y + h * np.dot(K[:-1].T, B)
#
# /opt/anaconda3/lib/python3.8/site-packages/scipy/integrate/_ivp/base.py in fun(t, y)
#     136         def fun(t, y):
#     137             self.nfev += 1
# --> 138             return self.fun_single(t, y)
#     139
#     140         self.fun = fun
#
# /opt/anaconda3/lib/python3.8/site-packages/scipy/integrate/_ivp/base.py in fun_single(t, y)
#     123         if vectorized:
#     124             def fun_single(t, y):
# --> 125                 return self._fun(t, y[:, None]).ravel()
#     126             fun_vectorized = self._fun
#     127         else:
#
# /opt/anaconda3/lib/python3.8/site-packages/scipy/integrate/_ivp/base.py in fun_wrapped(t, y)
#      18
#      19     def fun_wrapped(t, y):
# ---> 20         return np.asarray(fun(t, y), dtype=dtype)
#      21
#      22     return fun_wrapped, y0
#
# /opt/anaconda3/lib/python3.8/site-packages/scipy/integrate/_ivp/ivp.py in <lambda>(t, x, fun)
#     512         # additional parameters.  Pass in the original fun as a keyword
#     513         # argument to keep it in the scope of the lambda.
# --> 514         fun = lambda t, x, fun=fun: fun(t, x, *args)
#     515         jac = options.get('jac')
#     516         if callable(jac):
#
# ~/Documents/LANL_project/test_stuff/TOVsolver.py in TOV(p, y, EOS_e)
#      85
#      86     num2 = (y[2] ** 2 + y[2] * F_ode(p, y[0], y[1], EOS_e)
# ---> 87             + yQ_ode(p, y[0], y[1], EOS_e)) * (np.sqrt(y[0]) - 2 * y[1])
#      88     den2 = (EOS_e(p) + p) * (y[1] + 4 * pi * p * y[0] ** (3 / 2))
#      89
#
# ~/Documents/LANL_project/test_stuff/TOVsolver.py in yQ_ode(p, y, m, EOS_e)
#      33     b = np.sqrt(y) - 2 * m
#      34
# ---> 35     one = (a / b) * (5 * EOS_e(p) + 9 * p + EOS_e.derivative(nu=1)(p) * (EOS_e(p) + p))
#      36     two = -6 * np.sqrt(y) / b
#      37     three = -4 * (m / b + a * p / b) ** 2
#
# /opt/anaconda3/lib/python3.8/site-packages/scipy/interpolate/interpolate.py in derivative(self, nu)
#    1016             c2 = self.c[:-nu, :].copy()
#    1017
# -> 1018         if c2.shape[0] == 0:
#    1019             # derivative of order 0 is zero
#    1020             c2 = np.zeros((1,) + c2.shape[1:], dtype=c2.dtype)
#
# KeyboardInterrupt:

# %%
# window = 10

# for i in range(window):
#     %time cs5MRL_10[:,:,i] = TOVsolver.solve(cs5EOS[:,:,i], max_p)

# %%
# window = 20

# for i in range(window):
#     %time cs5MRL_20[:,:,i] = TOVsolver.solve(cs5EOS[:,:,i], max_p)

# %%
# cs5MRL = np.zeros(MRL_test.shape[0],MRL_test.shape[1],nsim)
# for i in range(nsim):
#     cs5MRL[:,:,i] = TOVsolver.solve(many_EOS_lin[:,:,i], max_p)
