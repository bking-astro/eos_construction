# %%
import numpy as np
import pandas as pd
import testsolver
import TOVsolver

# %%
# read in our EOS data
# The files contain n[0.16 fm^-3], p[Mev/fm^-3] and eps [Mev/fm^-3]

EOS_1 = pd.read_table('../data/3952.dat', header=None).to_numpy()
EOS_2 = pd.read_table('../data/8663.dat', header=None).to_numpy()
EOS_3 = pd.read_table('../data/13022.dat', header=None).to_numpy()

# %%
R_3952_test, M_3952_test, L_3952_test = testsolver.tov_solve(EOS_1[:,2], EOS_1[:,1])
# R_8663_test, M_8663_test, L_8663_test = testsolver.tov_solve(EOS_2[:,2], EOS_2[:,1])
# R_13022_test, M_13022_test, L_13022_test = testsolver.tov_solve(EOS_3[:,2], EOS_3[:,1])

# %%
MRL_3952 = TOVsolver.solve(EOS_1)
# Out:
# /Users/brendanking/Documents/LANL_project/test_stuff/TOVsolver.py:76: RuntimeWarning: invalid value encountered in sqrt
#   num0 = -2 * y[0] * (np.sqrt(y[0]) - 2 * y[1])
# /Users/brendanking/Documents/LANL_project/test_stuff/TOVsolver.py:77: RuntimeWarning: invalid value encountered in power
#   den0 = (EOS_e(p) + p) * (y[1] + 4 * pi * p * y[0] ** (3 / 2))
# /Users/brendanking/Documents/LANL_project/test_stuff/TOVsolver.py:81: RuntimeWarning: invalid value encountered in power
#   num1 = -4 * np.pi * EOS_e(p) * (y[0] ** (3 / 2)) * (np.sqrt(y[0]) - 2 * y[1])
# /Users/brendanking/Documents/LANL_project/test_stuff/TOVsolver.py:81: RuntimeWarning: invalid value encountered in sqrt
#   num1 = -4 * np.pi * EOS_e(p) * (y[0] ** (3 / 2)) * (np.sqrt(y[0]) - 2 * y[1])
# /Users/brendanking/Documents/LANL_project/test_stuff/TOVsolver.py:82: RuntimeWarning: invalid value encountered in power
#   den1 = (EOS_e(p) + p) * (y[1] + 4 * pi * p * y[0] ** (3 / 2))
# /Users/brendanking/Documents/LANL_project/test_stuff/TOVsolver.py:26: RuntimeWarning: invalid value encountered in sqrt
#   a = np.sqrt(y) / (np.sqrt(y) - 2 * m)
# /Users/brendanking/Documents/LANL_project/test_stuff/TOVsolver.py:32: RuntimeWarning: invalid value encountered in sqrt
#   a = 4 * pi * y * np.sqrt(y)
# /Users/brendanking/Documents/LANL_project/test_stuff/TOVsolver.py:33: RuntimeWarning: invalid value encountered in sqrt
#   b = np.sqrt(y) - 2 * m
# /Users/brendanking/Documents/LANL_project/test_stuff/TOVsolver.py:36: RuntimeWarning: invalid value encountered in sqrt
#   two = -6 * np.sqrt(y) / b
# /Users/brendanking/Documents/LANL_project/test_stuff/TOVsolver.py:87: RuntimeWarning: invalid value encountered in sqrt
#   + yQ_ode(p, y[0], y[1], EOS_e)) * (np.sqrt(y[0]) - 2 * y[1])
# /Users/brendanking/Documents/LANL_project/test_stuff/TOVsolver.py:88: RuntimeWarning: invalid value encountered in power
#   den2 = (EOS_e(p) + p) * (y[1] + 4 * pi * p * y[0] ** (3 / 2))

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(1,2, figsize=(16,8))

ax[0].plot(MRL_3952[:,1], MRL_3952[:,0], label='my sovler')
ax[0].plot(R_3952_test, M_3952_test, label='not my sovler')

ax[1].set_ylim(10,1000)
ax[1].plot(MRL_3952[:,0], MRL_3952[:,2], label='my sovler')
ax[1].plot(M_3952_test, L_3952_test, label='not my sovler')
ax[1].set_yscale('log')
plt.legend()

# %%
from scipy import interpolate

spl1 = interpolate.splrep(MRL_3952[:,0], MRL_3952[:,2],k=3) 
spl2 = interpolate.splrep(M_3952_test, L_3952_test,k=3)

def lamb_1(m):
    return interpolate.splev(m, spl1, der=0)

def lamb_2(m):
    return interpolate.splev(m, spl2, der=0)

m = np.linspace(0.5,2,num=50)

plt.plot(m,(lamb_1(m)-lamb_2(m))/lamb_1(m))
# plt.yscale('log')
